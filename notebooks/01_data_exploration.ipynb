# %%
{
 "cells": [
  {
   "cell_type": "code",
   "source": [
    "import pandas as pd\n",
    "from sqlalchemy import create_engine\n",
    "engine = create_engine('mysql+pymysql://root:your_password@localhost/phonepe_pulse')\n",
    "\n",
    "# Check tables\n",
    "df = pd.read_sql(\"SHOW TABLES\", engine)\n",
    "print(df)\n",
    "\n",
    "# Sample data\n",
    "df_user = pd.read_sql(\"SELECT * FROM aggregated_user LIMIT 10\", engine)\n",
    "df_user.head()"
   ]
  }
 ],
 "metadata": {}
}
# Out:
# {'cells': [{'cell_type': 'code',
#    'source': ['import pandas as pd\n',
#     'from sqlalchemy import create_engine\n',
#     "engine = create_engine('mysql+pymysql://root:your_password@localhost/phonepe_pulse')\n",
#     '\n',
#     '# Check tables\n',
#     'df = pd.read_sql("SHOW TABLES", engine)\n',
#     'print(df)\n',
#     '\n',
#     '# Sample data\n',
#     'df_user = pd.read_sql("SELECT * FROM aggregated_user LIMIT 10", engine)\n',
#     'df_user.head()']}],
#  'metadata': {}}
